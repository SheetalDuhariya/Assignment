# %%
# 1. Demonstrate three different methods for creating identical 2D arrays in NumPy. Provide the code for each method and the final output after each method

import numpy as np

# Method 1 : Using nested lists
arr1 = np.array([[1,2,3],[4,5,6]])
print("Method 1: ")
print(arr1)

# Method 2 : Using the zeros functions
arr2 = np.zeros((2,3))
arr2[0] = [1,2,3]
arr2[1] = [4,5,6]
print("\nMethod 2 :")
print(arr2)

# Method 3 : Using the full functions
arr3 = np.full((2,3),0)
arr3[0] = [1,2,3]
arr3[1] = [4,5,6]
print("\nMethod 3 :")
print(arr3)
# Out:
# Method 1:
# [[1 2 3]
#  [4 5 6]]
#
# Method 2 :
# [[1. 2. 3.]
#  [4. 5. 6.]]
#
# Method 3 :
# [[1 2 3]
#  [4 5 6]]

# %%
# 2. sing the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and Reshape that 1D array into a 2D array

import numpy as np

array_1d = np.linspace(1,10,100)
array_2d = array_1d.reshape(10,10)
print(array_2d)
# Out:
# [[ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#    1.54545455  1.63636364  1.72727273  1.81818182]
#  [ 1.90909091  2.          2.09090909  2.18181818  2.27272727  2.36363636
#    2.45454545  2.54545455  2.63636364  2.72727273]
#  [ 2.81818182  2.90909091  3.          3.09090909  3.18181818  3.27272727
#    3.36363636  3.45454545  3.54545455  3.63636364]
#  [ 3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#    4.27272727  4.36363636  4.45454545  4.54545455]
#  [ 4.63636364  4.72727273  4.81818182  4.90909091  5.          5.09090909
#    5.18181818  5.27272727  5.36363636  5.45454545]
#  [ 5.54545455  5.63636364  5.72727273  5.81818182  5.90909091  6.
#    6.09090909  6.18181818  6.27272727  6.36363636]
#  [ 6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#    7.          7.09090909  7.18181818  7.27272727]
#  [ 7.36363636  7.45454545  7.54545455  7.63636364  7.72727273  7.81818182
# ...

# %%
'''
 3. xplain the following terms
 The difference in np.array, np.asarray and np.asanyarray
 The difference between Deep copy and shallow copy


Function	                 Creates Copy?                       	Returns Subclass?
np.array	                   Yes                                     	No
np.asarray	                 No (unless needed)	                      No
np.asanyarray	               No (unless needed)	                     Yes


Copy Type	                Creates New Object?	                  Copies Nested Objects?
Shallow Copy	                Yes	                                    No
Deep Copy	                    Yes	                                    Yes

...

# %%
# 4 Generate a 3x3 array with random floating-point numbers between 5 and 20. Then, round each number in the array to 2 decimal places.

import numpy as np

arr = np.random.uniform(5,20,(3,3))

rounded_array = np.round(arr,2)

print("Random Array:")
print(arr)
print("\nRounded Array:")
print(rounded_array)
# Out:
# Random Array:
# [[14.7566638  12.32477936 10.46818276]
#  [12.77418283 19.88225809 14.19297309]
#  [14.57092159 15.35087924 16.72913357]]
#
# Rounded Array:
# [[14.76 12.32 10.47]
#  [12.77 19.88 14.19]
#  [14.57 15.35 16.73]]

# %%
# 5 . Create a NumPy array with random integers between 1 and 10 of shape (5, 6). After creating the array perform the following operations:

# a)Extract all even integers from array.

# b)Extract all odd integers from array

import numpy as np

arr = np.random.randint(1,10, size = (5,6))

arr_even = arr[arr%2==0]
arr_odd = arr[arr%2!=0]

print("Random Array:")
print(arr)
print("\n Even Integers:")
print(arr_even)
print("\n Odd Integers:")
print(arr_odd)
# Out:
# Random Array:
# [[8 4 3 1 2 5]
#  [9 3 7 9 1 5]
#  [8 6 5 7 4 2]
#  [4 4 4 4 3 7]
#  [8 1 1 8 9 5]]
#
#  Even Integers:
# [8 4 2 8 6 4 2 4 4 4 4 8 8]
#
#  Odd Integers:
# [3 1 5 9 3 7 9 1 5 5 7 3 7 1 1 9 5]

# %%
# 6. reate a 3D NumPy array of shape (3, 3, 3) containing random integers between 1 and 10. Perform the following operations:

# a) Find the indices of the maximum values along each depth level (third axis).

# b) Perform element-wise multiplication of between both array

import numpy as np

arr = np.random.randint(1,10, (3,3,3))

max_indices = np.argmax(arr,axis=2)

elementwise_multiplication = arr * arr

print("Random Array:")
print(arr)
print("\nIndices of Maximum Values:")
print(max_indices)
print("\nElement-wise Multiplication:")
print(elementwise_multiplication)
# Out:
# Random Array:
# [[[2 4 6]
#   [8 1 7]
#   [8 2 1]]
#
#  [[3 1 2]
#   [4 7 5]
#   [7 3 4]]
#
#  [[5 7 6]
#   [3 7 8]
#   [3 1 4]]]
#
# Indices of Maximum Values:
# [[2 0 0]
#  [0 1 0]
#  [1 2 2]]
#
# Element-wise Multiplication:
# [[[ 4 16 36]
#   [64  1 49]
#   [64  4  1]]
#
#  [[ 9  1  4]
#   [16 49 25]
#   [49  9 16]]
#
#  [[25 49 36]
#   [ 9 49 64]
#   [ 9  1 16]]]

# %%
import pandas as pd

file_url = "https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk"
df = pd.read_csv(file_url)

print("Original DataFrame:")
print(df)

# a) Clean the phone column to remove non numeric character
df['Phone'] = df ['Phone'].str.replace(r'\D','',regex=True)

# b) Convert to numeric, handling NaN values
# If you want to keep NaN as NaN:
df['Phone'] = pd.to_numeric(df['Phone'], errors='coerce')
# errors='coerce' will convert invalid parsing as NaN

#If you want to fill NaN with a specific value (e.g., 0):
# df['Phone'] = pd.to_numeric(df['Phone'], errors='coerce').fillna(0).astype(int)

# b) Display the data  fram after the transformation
print("\nTransformed DataFrame:")
print(df)

# Display the table attribute and data types of each column
print("\nTable Attributes and Data Types :")
print(df.dtypes)
# Out:
# Original DataFrame:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
# 8 . Perform the following tasks using people dataset:

# a) Read the 'data.csv' file using pandas, skipping the first 50 rows.

# b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.

# c) Display the first 10 rows of the filtered dataset.

# d) Extract the ‘Salary’' column as a Series and display its last 5 values
import pandas as pd

file_url = "https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk"
df = pd.read_csv(file_url, skiprows=range(1,50))

# Print the actual column names to identify discrepancies
print(df.columns)

# Adjust the column names in your selection to match the actual column names
# The original column names in the CSV are likely in title case or have spaces
filtered_df = df[['Last Name', 'Gender', 'Email', 'Phone', 'Salary']]
# Updated to use the actual column names from the CSV file

print("First 10 rows of the filtered dataset:")
print(filtered_df.head(10))

salary_series = filtered_df['Salary']  # Updated to use the actual column name
print("\nLast 5 values of the 'Salary' column:")
print(salary_series.tail(5))
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Gender', 'Email',
#        'Phone', 'Date of birth', 'Job Title', 'Salary'],
#       dtype='object')
# First 10 rows of the filtered dataset:
#   Last Name  Gender                         Email                   Phone  \
# 0    Mercer  Female  douglascontreras@example.net    +1-326-669-0118x4341
# 1    Zavala    Male          pamela64@example.net  001-859-448-9935x54536
# 2     Carey  Female     dianashepherd@example.net    001-274-739-8470x814
# 3     Hobbs  Female     ingramtiffany@example.org        241.179.9509x498
# 4    Reilly    Male    carriecrawford@example.org       207.797.8345x6177
# 5    Conrad    Male    fuentesclaudia@example.net    001-599-042-7428x143
# 6      Cole    Male        kaneaudrey@example.org            663-280-5834
# 7   Donovan    Male     rebekahsantos@example.net                     NaN
# 8    Little  Female           craig28@example.com       125.219.3673x0076
# ...

# %%
# 9. filter and select rows from the People_Dataset, where the “Last Name' column contains the name 'Duke', 'Gender' column contains the word Female and ‘Salary’ should be less than 8500

import pandas as pd

file_url = "https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk"

df = pd.read_csv(file_url)

filtered_df = df[(df['Last Name'].str.contains('Duke', case=False)) &
                 (df['Gender'].str.contains('Female', case=False)) &
                 (df['Salary'] < 8500)]
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [Index, User Id, First Name, Last Name, Gender, Email, Phone, Date of birth, Job Title, Salary]
# Index: []

# %%
# 10 . Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6?

import pandas as pd
import numpy as np

random_integers = np.random.randint(1,7 , 35)
df = pd.DataFrame(random_integers.reshape(7,5), columns = ['A', 'B', 'C', 'D', 'E'])

print(df)
# Out:
#    A  B  C  D  E
# 0  3  5  3  6  5
# 1  6  3  2  1  1
# 2  4  2  6  1  3
# 3  2  3  4  1  1
# 4  6  2  4  5  4
# 5  4  4  3  5  2
# 6  3  2  2  1  5

# %%
# 11. Create two different Series, each of length 50, with the following criteria:

# a) The first Series should contain random numbers ranging from 10 to 50.

# b) The second Series should contain random numbers ranging from 100 to 1000.

# c) Create a DataFrame by joining these Series by column, and, change the names of the columns to 'col1', 'col2', etc&

import pandas as pd
import numpy as np

sereis_1 = pd.Series(np.random.randint(10,51,50))
sereis_2 = pd.Series(np.random.randint(100,1001,50))

df = pd.DataFrame({'col1': sereis_1, 'col2': sereis_2})

print(df)
# Out:
#     col1  col2
# 0     35   639
# 1     15   614
# 2     37   730
# 3     31   509
# 4     31   263
# 5     50   402
# 6     22   704
# 7     20   799
# 8     45   297
# 9     17   759
# 10    29   249
# 11    43   909
# 12    48   310
# 13    22   206
# 14    28   107
# 15    49   784
# 16    35   178
# 17    11   895
# 18    14   858
# 19    33   920
# 20    29   908
# 21    36   411
# 22    11   586
# 23    36   610
# 24    37   324
# 25    38   285
# 26    18   400
# 27    24   271
# 28    30   677
# 29    15   224
# 30    49   909
# 31    43   433
# 32    11   547
# 33    49   916
# 34    41   346
# 35    48   102
# 36    41   622
# 37    22   121
# 38    36   332
# 39    25   150
# 40    13   622
# 41    45   238
# 42    37   489
# 43    27   967
# 44    41   981
# 45    47   806
# 46    29   391
# 47    26   908
# 48    23   987
# 49    29   397

# %%
# 12 Perform the following operations using people data set:

# a) Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset.

# b) Delete the rows containing any missing values.

# d) Print the final output also

import numpy as np
import pandas as pd

url = "https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk"
df = pd.read_csv(url)

df = df.drop(columns = ['Email', 'Phone', 'Date of birth'])
df = df.dropna()

print(df)
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
# 13 Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:

# a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.

# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.

# c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.

# d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.

# e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.

# f) Display a legend for the scatter plot, the horizontal line, and the vertical line


import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x,y , color = 'red' , marker = 'o')

plt.axhline(y=0.5, color = 'blue', linestyle = '--', label = 'y = 0.5')
plt.axvline(x=0.5, color = 'green', linestyle = ':', label = 'x = 0.5')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.title('Advanced Scatter Plot of Random Values')

plt.legend()
plt.show()

# %%
# 14 .Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and Perform the following tasks using Matplotlib:

# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and right y-axis for 'Humidity').

# b) Label the x-axis as 'Date'.

# c) Set the title of the plot as 'Temperature and Humidity Over Time'


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dates = pd.date_range(start = '2023-01-01', periods = 100 , freq = 'D')
temperature = np.random.uniform(20,30,100)
humidity = np.random.uniform(40,60,100)

df = pd.DataFrame({'Date': dates, 'Temperature': temperature, 'Humidity': humidity})

fig, ax1 = plt.subplots()

# a) Plot Temperature on left y-axis
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='tab:red')
ax1.plot(df['Date'], df['Temperature'], color='tab:red', label='Temperature')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Create a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.set_ylabel('Humidity (%)', color='tab:blue')
ax2.plot(df['Date'], df['Humidity'], color='tab:blue', label='Humidity')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# b) Label the x-axis
plt.xlabel('Date')

# c) Set the title of the plot
plt.title('Temperature and Humidity Over Time')

# Show the plot
plt.show()

# %%
# 15. Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib

# a) Plot a histogram of the data with 30 bins.

# b) Overlay a line plot representing the normal distribution's probability density function (PDF).

# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.

# d) Set the title of the plot as 'Histogram with PDF Overlay'.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# a) Generate data and plot histogram
data = np.random.randn(1000)  # Generate 1000 samples from a standard normal distribution
plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue', label='Histogram') # Plot histogram with 30 bins

# b) Overlay PDF
x = np.linspace(data.min(), data.max(), 100)  # Create x-values for PDF
pdf = stats.norm.pdf(x)  # Calculate PDF
plt.plot(x, pdf, 'r-', linewidth=2, label='PDF')  # Plot PDF

# c) Label axes
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# d) Set title
plt.title('Histogram with PDF Overlay')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
# 16 Set the title of the plot as 'Histogram with PDF Overlay'.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# a) Generate data and plot histogram
data = np.random.randn(1000)  # Generate 1000 samples from a standard normal distribution
plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue', label='Histogram') # Plot histogram with 30 bins

# b) Overlay PDF
x = np.linspace(data.min(), data.max(), 100)  # Create x-values for PDF
pdf = stats.norm.pdf(x)  # Calculate PDF
plt.plot(x, pdf, 'r-', linewidth=2, label='PDF')  # Plot PDF

# c) Label axes
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# d) Set title
plt.title('Histogram with PDF Overlay')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
# 17  Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(0)  # For reproducibility
x = np.random.randn(100)
y = np.random.randn(100)

# Create a DataFrame
df = pd.DataFrame({'X': x, 'Y': y})

# Define a function to determine the quadrant
def get_quadrant(row):
    if row['X'] >= 0 and row['Y'] >= 0:
        return 'Quadrant I'
    elif row['X'] < 0 and row['Y'] >= 0:
        return 'Quadrant II'
    elif row['X'] < 0 and row['Y'] < 0:
        return 'Quadrant III'
    else:
        return 'Quadrant IV'

# Apply the function to create a new column for quadrants
df['Quadrant'] = df.apply(get_quadrant, axis=1)

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=df, x='X', y='Y', hue='Quadrant', palette='Set1', s=100)

# Add legend, labels, and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')
plt.legend(title='Quadrants')

# Show the plot
plt.show()

# %%
# 18  With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'


import numpy as np
from bokeh.plotting import figure, show
from bokeh.models import Grid, LinearAxis
import matplotlib.pyplot as plt

# Generate data for the sine wave
x = np.linspace(0, 4*np.pi, 100)
y = np.sin(x)

# Create a new plot with a title and axis labels
p = figure(title="Sine Wave Function", x_axis_label="x", y_axis_label="sin(x)")

# Add the sine wave line to the plot
p.line(x, y, line_width=2)

# Add grid lines
p.xgrid.grid_line_color = "navy"
p.xgrid.grid_line_alpha = 0.4
p.ygrid.grid_line_color = "navy"
p.ygrid.grid_line_alpha = 0.4

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart'8

import numpy as np
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool

# Generate random categorical data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 100, size=len(categories))

# Create a DataFrame
data = pd.DataFrame({'Category': categories, 'Value': values})

# Create a ColumnDataSource
source = ColumnDataSource(data)

# Create a bar chart
p = figure(x_range=categories, title="Random Categorical Bar Chart",
           x_axis_label='Categories', y_axis_label='Values',
           tools="")

# Add bars to the plot
bars = p.vbar(x='Category', top='Value', source=source, width=0.9,
              line_color='white', fill_color='blue')

# Add hover tooltips
hover = HoverTool()
hover.tooltips = [("Category", "@Category"), ("Value", "@Value")]
p.add_tools(hover)

# Color bars based on their values
max_value = max(values)
colors = ["#%02x%02x%02x" % (int((value / max_value) * 255), 0, 0) for value in values]

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#20 . Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'8
import numpy as np
import plotly.express as px

# Generate random data
x = np.linspace(0, 10, 100)  # 100 points from 0 to 10
y = np.random.rand(100)       # Random values for y

# Create a DataFrame
data = {'x': x, 'y': y}

# Create a line plot
fig = px.line(data, x='x', y='y', title='Simple Line Plot')

# Label the axes
fig.update_layout(
    xaxis_title='X-axis',
    yaxis_title='Y-axis'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 21  Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart'.

import plotly.graph_objects as go
import numpy as np

# Generate random data
labels = ['Category A', 'Category B', 'Category C', 'Category D']
values = np.random.randint(1, 100, size=len(labels))

# Create the pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='label+percent', insidetextorientation='radial')])

# Set the title
fig.update_layout(title_text='Interactive Pie Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
